# %% [markdown]
# # Name: S.C.Sharon Lee
# # INTERN ID: CT08DS9284
#        This Project outlines for processing an image. In order to this, I have taken a sample picture from google and then converting it into the numpy array. Later

# %% [markdown]
#  # Reading an image file and converting it to a numpy array

# %%
import requests
url = 'http://cdn.wallpapersafari.com/96/50/hjWHdI.jpg'
response = requests.get(url)

# %%
# Check if the request was successful
if response.status_code == 200:
    with open('image.jpg', 'wb') as f:
        f.write(response.content)
    print('Image downloaded successfully.')
else:
    print(f'Failed to download image. Status code: {response.status_code}')
# Out:
# Image downloaded successfully.

# %%
from IPython.display import Image
# The Path to the image file
image_path = 'image.jpg'
# Displaying the image
Image(filename=image_path)

# %%
# importing the image module from matplotlib library
import matplotlib.image as mpimg
import matplotlib.pyplot as plt

# %%
img=mpimg.imread('image.jpg')

# %%
type(img)
# Out:
# numpy.ndarray

# %%
print(img.shape)
# Out:
# (1200, 1600, 3)

# %%
print(img)
# Out:
# [[[128 145 137]
#   [132 149 141]
#   [132 149 141]
#   ...
#   [175 148 101]
#   [174 147 100]
#   [174 147 100]]
#
#  [[121 138 130]
#   [123 140 132]
#   [123 140 132]
#   ...
#   [175 148 101]
#   [174 147 100]
#   [174 147 100]]
#
#  [[118 135 127]
#   [119 136 128]
#   [118 135 127]
#   ...
#   [175 148 101]
#   [174 147 100]
#   [174 147 100]]
#
#  ...
#
#  [[177 147  95]
#   [171 141  89]
#   [167 137  85]
#   ...
#   [ 58  68  59]
#   [ 57  67  58]
#   [ 55  65  56]]
#
#  [[173 143  91]
#   [170 140  88]
#   [170 140  88]
#   ...
#   [ 59  69  60]
#   [ 57  67  58]
#   [ 56  66  57]]
#
#  [[169 139  87]
#   [169 139  87]
#   [171 141  89]
#   ...
#   [ 60  70  61]
#   [ 58  68  59]
#   [ 56  66  57]]]

# %%
# Displaying the image from numpy array
img_plot = plt.imshow(img)
plt.show()

# %% [markdown]
# # Resizing an image using pillow library

# %%
from PIL import  Image

# %%
img = Image.open('image.jpg')
img_resized=img.resize((200,200))

# %%
img_resized.save('image_resized.jpg')

# %%
# Displaying the image from numpy array

img_res=mpimg.imread('image_resized.jpg')
img_res_plot = plt.imshow(img_res)
plt.show()

# %%
print(img_res.shape)
# Out:
# (200, 200, 3)

# %% [markdown]
# # RGB to Grayscale conversion using OpenCV

# %%
#importing open cv library
import cv2

# %%
# !pip install opencv-python
# Out:
# ...
#   Obtaining dependency information for opencv-python from https://files.pythonhosted.org/packages/ec/6c/fab8113424af5049f85717e8e527ca3773299a3c6b02506e66436e19874f/opencv_python-4.10.0.84-cp37-abi3-win_amd64.whl.metadata
# ...
#    ---------------------------------------- 0.0/38.8 MB ? eta -:--:--
#    ---------------------------------------- 0.0/38.8 MB ? eta -:--:--
#    ---------------------------------------- 0.1/38.8 MB 2.1 MB/s eta 0:00:19
#     --------------------------------------- 0.7/38.8 MB 6.2 MB/s eta 0:00:07
#     --------------------------------------- 0.9/38.8 MB 5.4 MB/s eta 0:00:07
#    - -------------------------------------- 1.1/38.8 MB 5.1 MB/s eta 0:00:08
#    - -------------------------------------- 1.1/38.8 MB 4.8 MB/s eta 0:00:08
#    - -------------------------------------- 1.1/38.8 MB 4.8 MB/s eta 0:00:08
#    - -------------------------------------- 1.1/38.8 MB 3.3 MB/s eta 0:00:12
#    - -------------------------------------- 1.8/38.8 MB 4.5 MB/s eta 0:00:09
# ...

# %%
#importing open cv library

import cv2

# %%
img =cv2.imread('image.jpg')

# %%
type(img)
# Out:
# numpy.ndarray

# %%
img.shape
# Out:
# (1200, 1600, 3)

# %%
grayscale_image=cv2.cvtColor(img,cv2.COLOR_RGB2GRAY)

# %%
type(grayscale_image)
# Out:
# numpy.ndarray

# %%
grayscale_image.shape
# Out:
# (1200, 1600)

# %%
import matplotlib.pyplot as plt
import cv2

# Loading RGB image
img_rgb = cv2.imread('image.jpg')

# Converting RGB to grayscale
img_gray = cv2.cvtColor(img_rgb, cv2.COLOR_BGR2GRAY)

# Displaying grayscale image using matplotlib
plt.imshow(img_gray, cmap='gray')
plt.axis('off')

# %%
cv2.imwrite('image_gray.jpg', img_gray)
# Out:
# True

# %%
cv2.imshow('Grayscale Image', img_gray)
